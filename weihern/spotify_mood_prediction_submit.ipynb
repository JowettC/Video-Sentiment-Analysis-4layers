# %%
#Script to obtain data 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

#Libraries to create the multiclass model
from keras.models import Sequential
from keras.layers import Dense

from keras.utils import np_utils
#Import tensorflow and disable the v2 behavior and eager mode
import tensorflow as tf
# tf.compat.v1.disable_eager_execution()
# tf.compat.v1.disable_v2_behavior()
from sklearn.model_selection import GridSearchCV


#Library to validate the model
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import metrics 
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, classification_report

# %%
df = pd.read_csv("songs_default.csv")

# %%
# encoding y variable 'mood' to be 1 for postive else 0 for negative
# drop duplicate name with the same mood

print(f'before drop: {df.shape}')
df['mood'] = df['mood'].replace(['calm', 'happy','angry','depress'], [1,1,0,0])
df.drop_duplicates(subset=['name', 'artist', 'mood'], keep='last',inplace=True)
print(f'after drop: {df.shape}')
# Out:
# before drop: (796, 20)
# after drop: (788, 20)

# %% [markdown]
# # Preparing Data

# %%
col_features = df.columns[7:-3]
scaler = MinMaxScaler()
scaler_fit = scaler.fit(df[col_features])
df1 = scaler.transform(df[col_features])

X = pd.DataFrame(df1, columns = col_features)
y = df[['mood']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=15)

# %% [markdown]
# # Running different ML Model

# %%
score_list = []
def test_scores(y_test,y_pred):
    # test recall and f1-score
    test_acc = metrics.accuracy_score(y_test, y_pred) 
    test_prec = metrics.precision_score(y_test, y_pred)
    test_recall = metrics.recall_score(y_test, y_pred) 
    test_f1 = metrics.f1_score(y_test, y_pred)
    scores = {'test' : [round(test_acc, 5), round(test_prec, 5), 
                        round(test_recall, 5), round(test_f1, 5)]}
    return scores

def train_scores(y_train,y_pred):
    # test recall and f1-score
    test_acc = metrics.accuracy_score(y_train, y_pred) 
    test_prec = metrics.precision_score(y_train, y_pred)
    test_recall = metrics.recall_score(y_train, y_pred) 
    test_f1 = metrics.f1_score(y_train, y_pred)
    scores = {'train' : [round(test_acc, 5), round(test_prec, 5), 
                        round(test_recall, 5), round(test_f1, 5)]}
    return scores

def runway_model(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train.values.ravel())
    y_pred = model.predict(X_test)
    scores = test_scores(y_test,y_pred)
    y_pred_train = model.predict(X_train)
    scores['train_score'] = train_scores(y_train,y_pred_train)
    return scores

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import GradientBoostingClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from xgboost import XGBClassifier
from sklearn.svm import LinearSVC

models = {
    'LinearSVC': LinearSVC(random_state=15),
    'Logistic Regression': LogisticRegression(max_iter= 10000, random_state= 15),
    'Decision Tree': DecisionTreeClassifier(random_state=15),
    'Random Forest': RandomForestClassifier(random_state= 15),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Neural Network': MLPClassifier(max_iter= 10000, random_state= 15),
    'Gradient Boosting': GradientBoostingClassifier(random_state= 15),
    'LightGBM': LGBMClassifier(random_state= 15),
    'CatBoost': CatBoostClassifier(verbose=0),
    'GNB': GaussianNB(),
    'Random Forest': RandomForestClassifier(random_state=15),
    'Adaboost': AdaBoostClassifier(random_state=15),
    'Adaboost_LSVC': AdaBoostClassifier(base_estimator=LinearSVC(random_state=15),random_state=15,algorithm='SAMME'),
}

# %%
score_list = []

for name, model in models.items():
    temp_dict = {}
    temp_dict[name] = runway_model(model, X_train, X_test, y_train, y_test)
    score_list.append(temp_dict)
score_list
# Out:
# [{'LinearSVC': {'test': [0.82278, 0.8, 0.8, 0.8],
#    'train_score': {'train': [0.79683, 0.81373, 0.77812, 0.79553]}}},
#  {'Logistic Regression': {'test': [0.79114, 0.78462, 0.72857, 0.75556],
#    'train_score': {'train': [0.78889, 0.82578, 0.74062, 0.78089]}}},
#  {'Decision Tree': {'test': [0.6962, 0.64865, 0.68571, 0.66667],
#    'train_score': {'train': [0.99683, 1.0, 0.99375, 0.99687]}}},
#  {'Random Forest': {'test': [0.76582, 0.73239, 0.74286, 0.73759],
#    'train_score': {'train': [0.99683, 0.99688, 0.99688, 0.99688]}}},
#  {'K-Nearest Neighbors': {'test': [0.76582, 0.71429, 0.78571, 0.7483],
#    'train_score': {'train': [0.83968, 0.83692, 0.85, 0.84341]}}},
#  {'Neural Network': {'test': [0.76582, 0.69412, 0.84286, 0.76129],
#    'train_score': {'train': [0.80952, 0.79762, 0.8375, 0.81707]}}},
#  {'Gradient Boosting': {'test': [0.78481, 0.75714, 0.75714, 0.75714],
#    'train_score': {'train': [0.95873, 0.96519, 0.95312, 0.95912]}}},
#  {'LightGBM': {'test': [0.78481, 0.74324, 0.78571, 0.76389],
#    'train_score': {'train': [0.99683, 0.99688, 0.99688, 0.99688]}}},
#  {'CatBoost': {'test': [0.81013, 0.77027, 0.81429, 0.79167],
#    'train_score': {'train': [0.99048, 0.99684, 0.98438, 0.99057]}}},
#  {'GNB': {'test': [0.67089, 0.84615, 0.31429, 0.45833],
#    'train_score': {'train': [0.66984, 0.87333, 0.40938, 0.55745]}}},
#  {'Adaboost': {'test': [0.76582, 0.72, 0.77143, 0.74483],
#    'train_score': {'train': [0.88571, 0.88994, 0.88438, 0.88715]}}},
#  {'Adaboost_LSVC': {'test': [0.78481, 0.76471, 0.74286, 0.75362],
#    'train_score': {'train': [0.78413, 0.80065, 0.76562, 0.78275]}}}]

# %% [markdown]
# # Hyperparameter tuning best ensemble model

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [{'n_estimators' : [10,100,1000,10000],
}]
best_clf = GridSearchCV(CatBoostClassifier(), param_grid = param_grid, scoring= 'f1', 
                   cv = 5, verbose = True, n_jobs = -1)

# %%
# Fit on data
best_clf.fit(X_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 1 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda3\lib\site-packages\catboost\core.py", line 5128, in fit
#     self._fit(X, y, cat_features, text_features, embedding_features, None, sample_weight, None, None, None, None, baseline, use_best_model,
#   File "D:\Anaconda3\lib\site-packages\catboost\core.py", line 2355, in _fit
#     self._train(
#   File "D:\Anaconda3\lib\site-packages\catboost\core.py", line 1759, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 4622, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 4671, in _catboost._CatBoost._train
# _catboost.CatBoostError: (The requested operation cannot be performed on a file with a user-mapped section open.) C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/util/system/file.cpp:857: can't open "catboost_info\\catboost_training.json" with mode CreateAlways (0x00000004)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.77146375 0.77579861 0.77186176        nan]
#   warnings.warn(
# Learning rate set to 0.069864
# 0:	learn: 0.6745992	total: 2.06ms	remaining: 204ms
# 1:	learn: 0.6567838	total: 4.09ms	remaining: 200ms
# 2:	learn: 0.6416843	total: 6.39ms	remaining: 207ms
# 3:	learn: 0.6248493	total: 8.49ms	remaining: 204ms
# 4:	learn: 0.6103756	total: 10.6ms	remaining: 201ms
# 5:	learn: 0.5942556	total: 12.7ms	remaining: 198ms
remaining: 0us
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000019862F74730>,
#              n_jobs=-1, param_grid=[{'n_estimators': [10, 100, 1000, 10000]}],
#              scoring='f1', verbose=True)

# %%
print(best_clf.best_params_)
# Out:
# {'n_estimators': 100}

# %%
model = CatBoostClassifier()
score = runway_model(model,X_train, X_test, y_train, y_test)
score
# Out:
# Learning rate set to 0.008458
# 0:	learn: 0.6871946	total: 2.56ms	remaining: 2.56s
# 1:	learn: 0.6810464	total: 4.73ms	remaining: 2.36s
# 2:	learn: 0.6762756	total: 7.4ms	remaining: 2.46s
# 3:	learn: 0.6701238	total: 9.84ms	remaining: 2.45s
# 4:	learn: 0.6650019	total: 12.1ms	remaining: 2.4s
# 5:	learn: 0.6608685	total: 14.4ms	remaining: 2.39s
# 6:	learn: 0.6552826	total: 17.1ms	remaining: 2.42s
# 7:	learn: 0.6501994	total: 19.5ms	remaining: 2.42s
# 8:	learn: 0.6455755	total: 22.1ms	remaining: 2.43s
# 9:	learn: 0.6414217	total: 25ms	remaining: 2.48s
# 10:	learn: 0.6370172	total: 28.3ms	remaining: 2.55s
# 11:	learn: 0.6323704	total: 31.3ms	remaining: 2.58s
# 12:	learn: 0.6271378	total: 34.3ms	remaining: 2.6s
# 13:	learn: 0.6237204	total: 37.1ms	remaining: 2.62s
# 14:	learn: 0.6189174	total: 39.9ms	remaining: 2.62s
# 15:	learn: 0.6153860	total: 42.7ms	remaining: 2.62s
# 16:	learn: 0.6116996	total: 45.5ms	remaining: 2.63s
# 17:	learn: 0.6074665	total: 48.2ms	remaining: 2.63s
# 18:	learn: 0.6033842	total: 50.8ms	remaining: 2.62s
# 19:	learn: 0.6003212	total: 53.4ms	remaining: 2.62s
# 20:	learn: 0.5968164	total: 56ms	remaining: 2.61s
# 21:	learn: 0.5930166	total: 58.6ms	remaining: 2.61s
# 22:	learn: 0.5894171	total: 61.1ms	remaining: 2.6s
# 23:	learn: 0.5859650	total: 63.7ms	remaining: 2.59s
# 24:	learn: 0.5834725	total: 66.2ms	remaining: 2.58s
# 25:	learn: 0.5805837	total: 68.7ms	remaining: 2.57s
# 26:	learn: 0.5768308	total: 71.7ms	remaining: 2.58s
# 27:	learn: 0.5736132	total: 74.5ms	remaining: 2.59s
# 28:	learn: 0.5706357	total: 77ms	remaining: 2.58s
# 29:	learn: 0.5670788	total: 79.3ms	remaining: 2.56s
# 30:	learn: 0.5638830	total: 81.5ms	remaining: 2.55s
# 31:	learn: 0.5606379	total: 83.8ms	remaining: 2.53s
# 32:	learn: 0.5575262	total: 86.5ms	remaining: 2.53s
# 33:	learn: 0.5543663	total: 88.8ms	remaining: 2.52s
# 34:	learn: 0.5520269	total: 90.9ms	remaining: 2.51s
# 35:	learn: 0.5493462	total: 93.1ms	remaining: 2.49s
# 36:	learn: 0.5468654	total: 95.8ms	remaining: 2.49s
# 37:	learn: 0.5442901	total: 98.6ms	remaining: 2.5s
# 38:	learn: 0.5414610	total: 101ms	remaining: 2.49s
# 39:	learn: 0.5388575	total: 103ms	remaining: 2.48s
# 40:	learn: 0.5364561	total: 106ms	remaining: 2.48s
# 41:	learn: 0.5337110	total: 109ms	remaining: 2.48s
# 284:	learn: 0.3068741	total: 699ms	remaining: 1.75s
# 285:	learn: 0.3064589	total: 701ms	remaining: 1.75s
# 286:	learn: 0.3059640	total: 704ms	remaining: 1.75s
# 287:	learn: 0.3054762	total: 706ms	remaining: 1.75s
# 288:	learn: 0.3050901	total: 709ms	remaining: 1.74s
# 289:	learn: 0.3045187	total: 711ms	remaining: 1.74s
# 290:	learn: 0.3041214	total: 714ms	remaining: 1.74s
# 291:	learn: 0.3036385	total: 716ms	remaining: 1.74s
# 292:	learn: 0.3031420	total: 719ms	remaining: 1.73s
# 293:	learn: 0.3026944	total: 721ms	remaining: 1.73s
# 294:	learn: 0.3021902	total: 724ms	remaining: 1.73s
# 295:	learn: 0.3018807	total: 726ms	remaining: 1.73s
# 296:	learn: 0.3016429	total: 729ms	remaining: 1.73s
# 297:	learn: 0.3013426	total: 732ms	remaining: 1.72s
# 298:	learn: 0.3011166	total: 734ms	remaining: 1.72s
# 299:	learn: 0.3008092	total: 737ms	remaining: 1.72s
# 300:	learn: 0.3004412	total: 739ms	remaining: 1.72s
# 301:	learn: 0.2998821	total: 742ms	remaining: 1.71s
# 302:	learn: 0.2994386	total: 744ms	remaining: 1.71s
# 303:	learn: 0.2990988	total: 746ms	remaining: 1.71s
# 304:	learn: 0.2987138	total: 749ms	remaining: 1.71s
# 305:	learn: 0.2983375	total: 751ms	remaining: 1.7s
# 306:	learn: 0.2981735	total: 753ms	remaining: 1.7s
# 307:	learn: 0.2976295	total: 756ms	remaining: 1.7s
# 308:	learn: 0.2972887	total: 758ms	remaining: 1.69s
# 309:	learn: 0.2968762	total: 760ms	remaining: 1.69s
# 310:	learn: 0.2965200	total: 763ms	remaining: 1.69s
# 311:	learn: 0.2960078	total: 766ms	remaining: 1.69s
# 312:	learn: 0.2955345	total: 768ms	remaining: 1.69s
# 313:	learn: 0.2950080	total: 771ms	remaining: 1.68s
# 314:	learn: 0.2947684	total: 773ms	remaining: 1.68s
# 315:	learn: 0.2942907	total: 776ms	remaining: 1.68s
# 316:	learn: 0.2939417	total: 778ms	remaining: 1.68s
# 317:	learn: 0.2936712	total: 780ms	remaining: 1.67s
# 318:	learn: 0.2933838	total: 782ms	remaining: 1.67s
# 319:	learn: 0.2930612	total: 784ms	remaining: 1.67s
# 320:	learn: 0.2926996	total: 787ms	remaining: 1.66s
# 321:	learn: 0.2922694	total: 789ms	remaining: 1.66s
# 322:	learn: 0.2919028	total: 792ms	remaining: 1.66s
# 323:	learn: 0.2914922	total: 794ms	remaining: 1.66s
# 324:	learn: 0.2910305	total: 796ms	remaining: 1.65s
# 325:	learn: 0.2907189	total: 798ms	remaining: 1.65s
# 326:	learn: 0.2901193	total: 801ms	remaining: 1.65s
# 327:	learn: 0.2897451	total: 803ms	remaining: 1.65s
# 328:	learn: 0.2892961	total: 805ms	remaining: 1.64s
# 329:	learn: 0.2890678	total: 808ms	remaining: 1.64s
# 330:	learn: 0.2887398	total: 811ms	remaining: 1.64s
# 331:	learn: 0.2883523	total: 815ms	remaining: 1.64s
# 332:	learn: 0.2879802	total: 818ms	remaining: 1.64s
# 429:	learn: 0.2572712	total: 1.08s	remaining: 1.43s
# 430:	learn: 0.2569754	total: 1.08s	remaining: 1.42s
# 431:	learn: 0.2566865	total: 1.08s	remaining: 1.42s
# 432:	learn: 0.2563402	total: 1.08s	remaining: 1.42s
# 433:	learn: 0.2561129	total: 1.09s	remaining: 1.42s
# 434:	learn: 0.2557608	total: 1.09s	remaining: 1.42s
# 435:	learn: 0.2552584	total: 1.09s	remaining: 1.41s
# 436:	learn: 0.2549348	total: 1.09s	remaining: 1.41s
# 437:	learn: 0.2546918	total: 1.1s	remaining: 1.41s
# 438:	learn: 0.2543050	total: 1.1s	remaining: 1.41s
# 439:	learn: 0.2540772	total: 1.1s	remaining: 1.4s
# 440:	learn: 0.2537675	total: 1.1s	remaining: 1.4s
# 441:	learn: 0.2535474	total: 1.11s	remaining: 1.4s
# 442:	learn: 0.2532704	total: 1.11s	remaining: 1.4s
# 443:	learn: 0.2529416	total: 1.11s	remaining: 1.39s
# 444:	learn: 0.2525721	total: 1.11s	remaining: 1.39s
# 445:	learn: 0.2523084	total: 1.12s	remaining: 1.39s
# 446:	learn: 0.2520736	total: 1.12s	remaining: 1.39s
# 447:	learn: 0.2518280	total: 1.12s	remaining: 1.38s
# 448:	learn: 0.2516464	total: 1.12s	remaining: 1.38s
# 449:	learn: 0.2514881	total: 1.13s	remaining: 1.38s
# 450:	learn: 0.2512932	total: 1.13s	remaining: 1.37s
# 451:	learn: 0.2510713	total: 1.13s	remaining: 1.37s
# 452:	learn: 0.2507948	total: 1.13s	remaining: 1.37s
# 453:	learn: 0.2504877	total: 1.14s	remaining: 1.36s
# 454:	learn: 0.2501463	total: 1.14s	remaining: 1.36s
# 455:	learn: 0.2497047	total: 1.14s	remaining: 1.36s
# 456:	learn: 0.2494727	total: 1.14s	remaining: 1.36s
# 457:	learn: 0.2493091	total: 1.15s	remaining: 1.35s
# 458:	learn: 0.2491005	total: 1.15s	remaining: 1.35s
# 459:	learn: 0.2487425	total: 1.15s	remaining: 1.35s
# 460:	learn: 0.2484858	total: 1.15s	remaining: 1.35s
# 461:	learn: 0.2482388	total: 1.15s	remaining: 1.34s
# 462:	learn: 0.2480738	total: 1.16s	remaining: 1.34s
# 463:	learn: 0.2477333	total: 1.16s	remaining: 1.34s
# 464:	learn: 0.2472892	total: 1.16s	remaining: 1.34s
# 465:	learn: 0.2470450	total: 1.16s	remaining: 1.33s
# 466:	learn: 0.2468070	total: 1.17s	remaining: 1.33s
# 467:	learn: 0.2466320	total: 1.17s	remaining: 1.33s
# 468:	learn: 0.2464399	total: 1.17s	remaining: 1.33s
# 469:	learn: 0.2461691	total: 1.17s	remaining: 1.32s
# 470:	learn: 0.2459560	total: 1.18s	remaining: 1.32s
# 471:	learn: 0.2456389	total: 1.18s	remaining: 1.32s
# 472:	learn: 0.2454331	total: 1.18s	remaining: 1.32s
# 473:	learn: 0.2451194	total: 1.18s	remaining: 1.31s
# 474:	learn: 0.2447854	total: 1.19s	remaining: 1.31s
# 475:	learn: 0.2444208	total: 1.19s	remaining: 1.31s
# 476:	learn: 0.2440717	total: 1.19s	remaining: 1.31s
# 477:	learn: 0.2438592	total: 1.19s	remaining: 1.3s
# 478:	learn: 0.2435154	total: 1.2s	remaining: 1.3s
# 479:	learn: 0.2432168	total: 1.2s	remaining: 1.3s
# 480:	learn: 0.2430195	total: 1.2s	remaining: 1.3s
# 481:	learn: 0.2428400	total: 1.2s	remaining: 1.29s
# 482:	learn: 0.2425717	total: 1.21s	remaining: 1.29s
# 483:	learn: 0.2423838	total: 1.21s	remaining: 1.29s
# 484:	learn: 0.2420572	total: 1.21s	remaining: 1.29s
# 485:	learn: 0.2418746	total: 1.21s	remaining: 1.28s
# 486:	learn: 0.2416649	total: 1.22s	remaining: 1.28s
# 487:	learn: 0.2412833	total: 1.22s	remaining: 1.28s
# 488:	learn: 0.2409701	total: 1.22s	remaining: 1.28s
# 489:	learn: 0.2407256	total: 1.23s	remaining: 1.27s
# 490:	learn: 0.2404761	total: 1.23s	remaining: 1.27s
# 491:	learn: 0.2402627	total: 1.23s	remaining: 1.27s
# 492:	learn: 0.2400942	total: 1.23s	remaining: 1.27s
# 493:	learn: 0.2398217	total: 1.24s	remaining: 1.26s
# 494:	learn: 0.2394575	total: 1.24s	remaining: 1.26s
# 495:	learn: 0.2391764	total: 1.24s	remaining: 1.26s
# 496:	learn: 0.2389781	total: 1.24s	remaining: 1.26s
# 497:	learn: 0.2388319	total: 1.24s	remaining: 1.25s
# 498:	learn: 0.2385410	total: 1.25s	remaining: 1.25s
# 499:	learn: 0.2382595	total: 1.25s	remaining: 1.25s
# 500:	learn: 0.2380816	total: 1.25s	remaining: 1.25s
# 501:	learn: 0.2377700	total: 1.25s	remaining: 1.24s
# 502:	learn: 0.2374437	total: 1.26s	remaining: 1.24s
# 503:	learn: 0.2371686	total: 1.26s	remaining: 1.24s
# 504:	learn: 0.2369413	total: 1.26s	remaining: 1.24s
# 505:	learn: 0.2366258	total: 1.26s	remaining: 1.23s
# 506:	learn: 0.2364079	total: 1.27s	remaining: 1.23s
# 507:	learn: 0.2361513	total: 1.27s	remaining: 1.23s
# 508:	learn: 0.2360199	total: 1.27s	remaining: 1.23s
# 509:	learn: 0.2357714	total: 1.27s	remaining: 1.22s
# 510:	learn: 0.2355401	total: 1.28s	remaining: 1.22s
# 511:	learn: 0.2351885	total: 1.28s	remaining: 1.22s
# 512:	learn: 0.2347949	total: 1.28s	remaining: 1.22s
# 513:	learn: 0.2345794	total: 1.28s	remaining: 1.21s
# 514:	learn: 0.2344016	total: 1.29s	remaining: 1.21s
# 515:	learn: 0.2341663	total: 1.29s	remaining: 1.21s
# 516:	learn: 0.2339966	total: 1.29s	remaining: 1.21s
# 517:	learn: 0.2337826	total: 1.29s	remaining: 1.2s
# 518:	learn: 0.2335961	total: 1.3s	remaining: 1.21s
# 519:	learn: 0.2333687	total: 1.31s	remaining: 1.21s
# 520:	learn: 0.2331335	total: 1.31s	remaining: 1.21s
# 521:	learn: 0.2328371	total: 1.31s	remaining: 1.2s
# 522:	learn: 0.2326540	total: 1.31s	remaining: 1.2s
# 523:	learn: 0.2324438	total: 1.32s	remaining: 1.2s
# 524:	learn: 0.2320701	total: 1.32s	remaining: 1.19s
# 525:	learn: 0.2319041	total: 1.32s	remaining: 1.19s
# 526:	learn: 0.2316915	total: 1.32s	remaining: 1.19s
# 527:	learn: 0.2313981	total: 1.33s	remaining: 1.19s
# 528:	learn: 0.2311669	total: 1.33s	remaining: 1.18s
# 529:	learn: 0.2310113	total: 1.33s	remaining: 1.18s
# 530:	learn: 0.2307748	total: 1.33s	remaining: 1.18s
# 531:	learn: 0.2306380	total: 1.34s	remaining: 1.18s
# 532:	learn: 0.2304940	total: 1.34s	remaining: 1.17s
# 533:	learn: 0.2302122	total: 1.34s	remaining: 1.17s
# 534:	learn: 0.2299385	total: 1.34s	remaining: 1.17s
# 535:	learn: 0.2296659	total: 1.35s	remaining: 1.17s
# 536:	learn: 0.2294768	total: 1.35s	remaining: 1.16s
# 537:	learn: 0.2292260	total: 1.35s	remaining: 1.16s
# 538:	learn: 0.2290762	total: 1.35s	remaining: 1.16s
# 539:	learn: 0.2288597	total: 1.36s	remaining: 1.16s
# 540:	learn: 0.2286278	total: 1.36s	remaining: 1.15s
# 541:	learn: 0.2283496	total: 1.36s	remaining: 1.15s
# 542:	learn: 0.2281130	total: 1.36s	remaining: 1.15s
# 543:	learn: 0.2279703	total: 1.37s	remaining: 1.15s
# 544:	learn: 0.2276243	total: 1.37s	remaining: 1.14s
# 545:	learn: 0.2273787	total: 1.37s	remaining: 1.14s
# 546:	learn: 0.2271116	total: 1.37s	remaining: 1.14s
# 547:	learn: 0.2267157	total: 1.38s	remaining: 1.14s
# 548:	learn: 0.2264541	total: 1.38s	remaining: 1.13s
# 549:	learn: 0.2263020	total: 1.38s	remaining: 1.13s
# 550:	learn: 0.2261049	total: 1.38s	remaining: 1.13s
# 551:	learn: 0.2258652	total: 1.39s	remaining: 1.13s
# 552:	learn: 0.2257529	total: 1.39s	remaining: 1.12s
# 553:	learn: 0.2255006	total: 1.39s	remaining: 1.12s
# 554:	learn: 0.2253502	total: 1.4s	remaining: 1.12s
# 555:	learn: 0.2250536	total: 1.4s	remaining: 1.12s
# 556:	learn: 0.2249043	total: 1.4s	remaining: 1.11s
# 557:	learn: 0.2247228	total: 1.4s	remaining: 1.11s
# 558:	learn: 0.2243845	total: 1.41s	remaining: 1.11s
# 559:	learn: 0.2241884	total: 1.41s	remaining: 1.1s
# 560:	learn: 0.2239853	total: 1.41s	remaining: 1.1s
# 561:	learn: 0.2237919	total: 1.41s	remaining: 1.1s
# 562:	learn: 0.2235297	total: 1.41s	remaining: 1.1s
# 563:	learn: 0.2231410	total: 1.42s	remaining: 1.09s
# 564:	learn: 0.2228962	total: 1.42s	remaining: 1.09s
# 565:	learn: 0.2226956	total: 1.42s	remaining: 1.09s
# 566:	learn: 0.2225453	total: 1.42s	remaining: 1.09s
# 567:	learn: 0.2222514	total: 1.43s	remaining: 1.08s
# 568:	learn: 0.2220028	total: 1.43s	remaining: 1.08s
# 569:	learn: 0.2217423	total: 1.43s	remaining: 1.08s
# Tuned model is not better as CatBoost default setting is able to identify the best solution for it. as show above, train_score is 99% based on default setting

# %% [markdown]
# # Keras Model

# %%
# Keras
def base_model():
    #Create the model
    model = Sequential()
    #Add 1 layer with 32 nodes  with relu function
#     model.add(Dense(32,input_dim=X_train.shape[1],activation='relu'))
    #Add 1 layer with 16 nodes with relu function
    model.add(Dense(16,input_dim=X_train.shape[1],activation='relu'))
    #Add 1 layer with 8 nodes with relu function
    model.add(Dense(8,input_dim=X_train.shape[1],activation='relu'))
    #Add 1 layer with output 2 and sigmoid function
    model.add(Dense(1, activation='sigmoid'))
    #Compile the model using sigmoid loss function and adam optim
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# # fix random seed for reproducibility
# seed = 20
# tf.random.set_seed(seed)

# model = base_model()
# history = model.fit(X_train, y_train, epochs=100, batch_size=100, validation_data = (X_test,y_test))
# y_pred = model.predict(X_test)
# y_pred =(y_pred>0.5)
# scores = test_scores(y_test,y_pred)
# score_list.append({"Keras":scores})
# print(scores)

# %% [markdown]
# # Hyperparamenter Tuning for CNN Model (Keras)

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasClassifier

# fix random seed for reproducibility
seed = 20
tf.random.set_seed(seed)

# create model
model = KerasClassifier(model=base_model, verbose=0)
# define the grid search parameters
batch_size = [100, 200, 300, 400]
epochs = [100, 200, 300]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train.to_numpy(), y_train.to_numpy())
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
print(f'Best estimator: {grid_result.best_estimator_}')
# Out:
# Best: 0.790476 using {'batch_size': 100, 'epochs': 200}
# Best estimator: KerasClassifier(
# 	model=<function base_model at 0x00000198678C6D30>
# 	build_fn=None
# 	warm_start=False
# 	random_state=None
# 	optimizer=rmsprop
# 	loss=None
# 	metrics=None
# 	batch_size=100
# 	validation_batch_size=None
# 	verbose=0
# 	callbacks=None
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=200
# 	class_weight=None
# )

# %%
# Update model accordingly to best param Best: 0.790476 using {'batch_size': 100, 'epochs': 200}
# fix random seed for reproducibility
seed = 20
tf.random.set_seed(seed)

model = base_model()
model.fit(X_train, y_train, epochs=100, batch_size=200, validation_data = (X_test,y_test))
y_pred = model.predict(X_test)
y_pred =(y_pred>0.5)
scores = test_scores(y_test,y_pred)
score_list.append({"Keras_Tuned":scores})
print(scores)

y_pred_train = model.predict(X_train)
y_pred_train =(y_pred_train>0.5)
scores = train_scores(y_train,y_pred_train)
score_list.append({"Keras_Tuned":scores})
print(scores)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 117ms/step - loss: 0.6559 - accuracy: 0.6635 - val_loss: 0.6644 - val_accuracy: 0.5823
# Epoch 2/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6508 - accuracy: 0.6825 - val_loss: 0.6593 - val_accuracy: 0.6076
# Epoch 3/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6460 - accuracy: 0.7032 - val_loss: 0.6541 - val_accuracy: 0.6139
# Epoch 4/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6416 - accuracy: 0.7222 - val_loss: 0.6492 - val_accuracy: 0.6139
# Epoch 5/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6373 - accuracy: 0.7175 - val_loss: 0.6442 - val_accuracy: 0.6646
# Epoch 6/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6333 - accuracy: 0.7190 - val_loss: 0.6391 - val_accuracy: 0.6835
# Epoch 7/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6291 - accuracy: 0.7381 - val_loss: 0.6344 - val_accuracy: 0.7342
# Epoch 8/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.6253 - accuracy: 0.7302 - val_loss: 0.6299 - val_accuracy: 0.7595
# Epoch 9/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6216 - accuracy: 0.7381 - val_loss: 0.6262 - val_accuracy: 0.7405
# Epoch 10/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6181 - accuracy: 0.7349 - val_loss: 0.6228 - val_accuracy: 0.7468
# Epoch 11/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5327 - accuracy: 0.7603 - val_loss: 0.5448 - val_accuracy: 0.7405
# Epoch 43/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5305 - accuracy: 0.7603 - val_loss: 0.5416 - val_accuracy: 0.7468
# Epoch 44/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5286 - accuracy: 0.7587 - val_loss: 0.5389 - val_accuracy: 0.7342
# Epoch 45/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5266 - accuracy: 0.7556 - val_loss: 0.5368 - val_accuracy: 0.7342
# Epoch 46/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5246 - accuracy: 0.7556 - val_loss: 0.5352 - val_accuracy: 0.7468
# Epoch 47/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5224 - accuracy: 0.7587 - val_loss: 0.5340 - val_accuracy: 0.7468
# Epoch 48/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5201 - accuracy: 0.7635 - val_loss: 0.5321 - val_accuracy: 0.7468
# Epoch 49/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5181 - accuracy: 0.7651 - val_loss: 0.5300 - val_accuracy: 0.7468
# Epoch 50/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5161 - accuracy: 0.7667 - val_loss: 0.5291 - val_accuracy: 0.7405
# Epoch 51/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5139 - accuracy: 0.7683 - val_loss: 0.5289 - val_accuracy: 0.7532
# Epoch 52/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5121 - accuracy: 0.7714 - val_loss: 0.5281 - val_accuracy: 0.7658
# Epoch 53/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5101 - accuracy: 0.7730 - val_loss: 0.5255 - val_accuracy: 0.7595
# Epoch 54/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5079 - accuracy: 0.7714 - val_loss: 0.5216 - val_accuracy: 0.7405
# Epoch 55/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5064 - accuracy: 0.7667 - val_loss: 0.5181 - val_accuracy: 0.7468
# Epoch 56/200
# 3/3 [==============================] - 0s 18ms/step - loss: 0.5052 - accuracy: 0.7667 - val_loss: 0.5162 - val_accuracy: 0.7468
# Epoch 57/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.5032 - accuracy: 0.7698 - val_loss: 0.5152 - val_accuracy: 0.7405
# Epoch 58/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5012 - accuracy: 0.7667 - val_loss: 0.5140 - val_accuracy: 0.7405
# Epoch 59/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4991 - accuracy: 0.7619 - val_loss: 0.5131 - val_accuracy: 0.7405
# Epoch 60/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4974 - accuracy: 0.7683 - val_loss: 0.5128 - val_accuracy: 0.7722
# Epoch 61/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4957 - accuracy: 0.7746 - val_loss: 0.5126 - val_accuracy: 0.7975
# Epoch 62/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4939 - accuracy: 0.7746 - val_loss: 0.5120 - val_accuracy: 0.7975
# Epoch 63/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4923 - accuracy: 0.7778 - val_loss: 0.5108 - val_accuracy: 0.7975
# Epoch 64/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4907 - accuracy: 0.7810 - val_loss: 0.5083 - val_accuracy: 0.7975
# Epoch 65/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4889 - accuracy: 0.7794 - val_loss: 0.5050 - val_accuracy: 0.7848
# Epoch 66/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4872 - accuracy: 0.7730 - val_loss: 0.5023 - val_accuracy: 0.7595
# Epoch 67/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4855 - accuracy: 0.7730 - val_loss: 0.4998 - val_accuracy: 0.7468
# Epoch 68/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4841 - accuracy: 0.7683 - val_loss: 0.4978 - val_accuracy: 0.7532
# Epoch 69/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4826 - accuracy: 0.7683 - val_loss: 0.4963 - val_accuracy: 0.7532
# Epoch 70/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4810 - accuracy: 0.7683 - val_loss: 0.4952 - val_accuracy: 0.7468
# Epoch 71/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4793 - accuracy: 0.7667 - val_loss: 0.4947 - val_accuracy: 0.7658
# Epoch 72/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4775 - accuracy: 0.7762 - val_loss: 0.4941 - val_accuracy: 0.7848
# Epoch 73/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.
200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4441 - accuracy: 0.7857 - val_loss: 0.4608 - val_accuracy: 0.8165
# Epoch 105/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4426 - accuracy: 0.7889 - val_loss: 0.4629 - val_accuracy: 0.8038
# Epoch 106/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4418 - accuracy: 0.7952 - val_loss: 0.4647 - val_accuracy: 0.8038
# Epoch 107/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4417 - accuracy: 0.7968 - val_loss: 0.4645 - val_accuracy: 0.8038
# Epoch 108/200
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4409 - accuracy: 0.7921 - val_loss: 0.4623 - val_accuracy: 0.8038
# Epoch 109/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4398 - accuracy: 0.7968 - val_loss: 0.4596 - val_accuracy: 0.7975
# Epoch 110/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4387 - accuracy: 0.7937 - val_loss: 0.4560 - val_accuracy: 0.8165
# Epoch 111/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4382 - accuracy: 0.7905 - val_loss: 0.4533 - val_accuracy: 0.8038
# Epoch 112/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4388 - accuracy: 0.7873 - val_loss: 0.4519 - val_accuracy: 0.7911
# Epoch 113/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4381 - accuracy: 0.7905 - val_loss: 0.4526 - val_accuracy: 0.8101
# Epoch 114/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4368 - accuracy: 0.7905 - val_loss: 0.4536 - val_accuracy: 0.8165
# Epoch 115/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4358 - accuracy: 0.7889 - val_loss: 0.4530 - val_accuracy: 0.8165
# Epoch 116/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4354 - accuracy: 0.7889 - val_loss: 0.4534 - val_accuracy: 0.8038
# Epoch 117/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4346 - accuracy: 0.7984 - val_loss: 0.4541 - val_accuracy: 0.7975
# Epoch 118/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4340 - accuracy: 0.8048 - val_loss: 0.4543 - val_accuracy: 0.7975
# Epoch 119/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4334 - accuracy: 0.8000 - val_loss: 0.4543 - val_accuracy: 0.7975
# Epoch 120/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4328 - accuracy: 0.7968 - val_loss: 0.4549 - val_accuracy: 0.8038
# Epoch 121/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4327 - accuracy: 0.8000 - val_loss: 0.4555 - val_accuracy: 0.8038
# Epoch 122/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4322 - accuracy: 0.7984 - val_loss: 0.4548 - val_accuracy: 0.8038
# Epoch 123/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4316 - accuracy: 0.8000 - val_loss: 0.4535 - val_accuracy: 0.8038
# Epoch 124/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4310 - accuracy: 0.8000 - val_loss: 0.4521 - val_accuracy: 0.7975
# Epoch 125/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4304 - accuracy: 0.8016 - val_loss: 0.4505 - val_accuracy: 0.7975
# Epoch 126/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4297 - accuracy: 0.8048 - val_loss: 0.4492 - val_accuracy: 0.7911
# Epoch 127/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4295 - accuracy: 0.8032 - val_loss: 0.4477 - val_accuracy: 0.7975
# Epoch 128/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4289 - accuracy: 0.8000 - val_loss: 0.4463 - val_accuracy: 0.8038
# Epoch 129/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4286 - accuracy: 0.7968 - val_loss: 0.4447 - val_accuracy: 0.8038
# Epoch 130/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4284 - accuracy: 0.7968 - val_loss: 0.4438 - val_accuracy: 0.8038
# Epoch 131/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4281 - accuracy: 0.7968 - val_loss: 0.4440 - val_accuracy: 0.8038
# Epoch 132/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4273 - accuracy: 0.7968 - val_loss: 0.4446 - val_accuracy: 0.7975
# Epoch 133/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4265 - accuracy: 0.7984 - val_loss: 0.4452 - val_accuracy: 0.7911
# Epoch 134/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4258 - accuracy: 0.8063 - val_loss: 0.4478 - val_accuracy: 0.8165
# Epoch 135/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4257 - accuracy: 0.8016 - val_loss: 0.4510 - val_accuracy: 0.8038
# Epoch 136/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4260 - accuracy: 0.7968 - val_loss: 0.4520 - val_accuracy: 0.7975
# Epoch 137/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4261 - accuracy: 0.7952 - val_loss: 0.4512 - val_accuracy: 0.7975
# Epoch 138/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4252 - accuracy: 0.7984 - val_loss: 0.4478 - val_accuracy: 0.8038
# Epoch 139/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4242 - accuracy: 0.8048 - val_loss: 0.4448 - val_accuracy: 0.8165
# Epoch 140/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4233 - accuracy: 0.8063 - val_loss: 0.4435 - val_accuracy: 0.8038
# Epoch 141/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4229 - accuracy: 0.8048 - val_loss: 0.4427 - val_accuracy: 0.8038
# Epoch 142/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4225 - accuracy: 0.8048 - val_loss: 0.4430 - val_accuracy: 0.8165
# Epoch 143/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4220 - accuracy: 0.8048 - val_loss: 0.4441 - val_accuracy: 0.8038
# Epoch 144/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4217 - accuracy: 0.8111 - val_loss: 0.4450 - val_accuracy: 0.8038
# Epoch 145/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4215 - accuracy: 0.8079 - val_loss: 0.4445 - val_accuracy: 0.8038
# Epoch 146/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4210 - accuracy: 0.8079 - val_loss: 0.4430 - val_accuracy: 0.8038
# Epoch 147/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4205 - accuracy: 0.8095 - val_loss: 0.4420 - val_accuracy: 0.8038
# Epoch 148/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4200 - accuracy: 0.8095 - val_loss: 0.4419 - val_accuracy: 0.8038
# Epoch 149/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4197 - accuracy: 0.8063 - val_loss: 0.4426 - val_accuracy: 0.7975
# Epoch 150/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4193 - accuracy: 0.8032 - val_loss: 0.4437 - val_accuracy: 0.7911
# Epoch 151/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4197 - accuracy: 0.8016 - val_loss: 0.4442 - val_accuracy: 0.7911
# Epoch 152/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4192 - accuracy: 0.8016 - val_loss: 0.4417 - val_accuracy: 0.7975
# Epoch 153/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4181 - accuracy: 0.8032 - val_loss: 0.4382 - val_accuracy: 0.8038
# Epoch 154/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4178 - accuracy: 0.8063 - val_loss: 0.4361 - val_accuracy: 0.7975
# Epoch 155/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4177 - accuracy: 0.8048 - val_loss: 0.4347 - val_accuracy: 0.7911
# Epoch 156/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4177 - accuracy: 0.8063 - val_loss: 0.4340 - val_accuracy: 0.7911
# Epoch 157/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4176 - accuracy: 0.8063 - val_loss: 0.4347 - val_accuracy: 0.7911
# Epoch 158/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4168 - accuracy: 0.8048 - val_loss: 0.4369 - val_accuracy: 0.7975
# Epoch 159/200
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4160 - accuracy: 0.8095 - val_loss: 0.4407 - val_accuracy: 0.7911
# Epoch 160/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4166 - accuracy: 0.8048 - val_loss: 0.4450 - val_accuracy: 0.7975
# Epoch 161/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4182 - accuracy: 0.7857 - val_loss: 0.4460 - val_accuracy: 0.7975
# Epoch 162/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4182 - accuracy: 0.7889 - val_loss: 0.4424 - val_accuracy: 0.7975
# Epoch 163/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4158 - accuracy: 0.8032 - val_loss: 0.4384 - val_accuracy: 0.8038
# Epoch 164/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4147 - accuracy: 0.8048 - val_loss: 0.4349 - val_accuracy: 0.7975
# Epoch 165/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4150 - accuracy: 0.8063 - val_loss: 0.4333 - val_accuracy: 0.7911
# Epoch 166/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4153 - accuracy: 0.8063 - val_loss: 0.4328 - val_accuracy: 0.7911
# Epoch 167/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4152 - accuracy: 0.8063 - val_loss: 0.4323 - val_accuracy: 0.7975
# Epoch 168/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4154 - accuracy: 0.8048 - val_loss: 0.4325 - val_accuracy: 0.7911
# Epoch 169/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4144 - accuracy: 0.8095 - val_loss: 0.4337 - val_accuracy: 0.7911
# Epoch 170/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4136 - accuracy: 0.8079 - val_loss: 0.4353 - val_accuracy: 0.8038
# Epoch 171/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4129 - accuracy: 0.8111 - val_loss: 0.4363 - val_accuracy: 0.8038
# Epoch 172/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4129 - accuracy: 0.8048 - val_loss: 0.4376 - val_accuracy: 0.7975
# Epoch 173/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4134 - accuracy: 0.8048 - val_loss: 0.4370 - val_accuracy: 0.7975
# Epoch 174/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4129 - accuracy: 0.8016 - val_loss: 0.4346 - val_accuracy: 0.8038
# Epoch 175/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4119 - accuracy: 0.8095 - val_loss: 0.4336 - val_accuracy: 0.8038
# Epoch 176/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4116 - accuracy: 0.8079 - val_loss: 0.4327 - val_accuracy: 0.7975
# Epoch 177/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4115 - accuracy: 0.8095 - val_loss: 0.4323 - val_accuracy: 0.7975
# Epoch 178/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4114 - accuracy: 0.8111 - val_loss: 0.4323 - val_accuracy: 0.7975
# Epoch 179/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4111 - accuracy: 0.8111 - val_loss: 0.4313 - val_accuracy: 0.7848
# Epoch 180/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4117 - accuracy: 0.8063 - val_loss: 0.4300 - val_accuracy: 0.7848
# Epoch 181/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4119 - accuracy: 0.8095 - val_loss: 0.4301 - val_accuracy: 0.7848
# Epoch 182/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4114 - accuracy: 0.8095 - val_loss: 0.4313 - val_accuracy: 0.7911
# Epoch 183/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4107 - accuracy: 0.8127 - val_loss: 0.4339 - val_accuracy: 0.7975
# Epoch 184/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4097 - accuracy: 0.8079 - val_loss: 0.4375 - val_accuracy: 0.7911
# Epoch 185/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4106 - accuracy: 0.8016 - val_loss: 0.4427 - val_accuracy: 0.7975
# Epoch 186/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4126 - accuracy: 0.7937 - val_loss: 0.4450 - val_accuracy: 0.7911
# Epoch 187/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4133 - accuracy: 0.7921 - val_loss: 0.4423 - val_accuracy: 0.7975
# Epoch 188/200
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4111 - accuracy: 0.7937 - val_loss: 0.4358 - val_accuracy: 0.7911
# Epoch 189/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4098 - accuracy: 0.8016 - val_loss: 0.4303 - val_accuracy: 0.7911
# Epoch 190/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4092 - accuracy: 0.8111 - val_loss: 0.4285 - val_accuracy: 0.7848
# Epoch 191/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4102 - accuracy: 0.8111 - val_loss: 0.4283 - val_accuracy: 0.7848
# Epoch 192/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4098 - accuracy: 0.8079 - val_loss: 0.4288 - val_accuracy: 0.7848
# Epoch 193/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4089 - accuracy: 0.8127 - val_loss: 0.4293 - val_accuracy: 0.7975
# Epoch 194/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4084 - accuracy: 0.8127 - val_loss: 0.4295 - val_accuracy: 0.7975
# Epoch 195/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4082 - accuracy: 0.8127 - val_loss: 0.4299 - val_accuracy: 0.7975
# Epoch 196/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4079 - accuracy: 0.8127 - val_loss: 0.4309 - val_accuracy: 0.7975
# Epoch 197/200
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4078 - accuracy: 0.8111 - val_loss: 0.4321 - val_accuracy: 0.8038
# Epoch 198/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4076 - accuracy: 0.8063 - val_loss: 0.4335 - val_accuracy: 0.7975
# Epoch 199/200
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4074 - accuracy: 0.8032 - val_loss: 0.4339 - val_accuracy: 0.7911
# Epoch 200/200
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4072 - accuracy: 0.8032 - val_loss: 0.4327 - val_accuracy: 0.7975
# 5/5 [==============================] - 0s 1ms/step
# {'test': [0.79747, 0.75, 0.81429, 0.78082]}
# 20/20 [==============================] - 0s 947us/step
# {'train': [0.80476, 0.81672, 0.79375, 0.80507]}

# %% [markdown]
# # Overall models score

# %%
score_list
# Out:
# [{'LinearSVC': {'test': [0.82278, 0.8, 0.8, 0.8],
#    'train_score': {'train': [0.79683, 0.81373, 0.77812, 0.79553]}}},
#  {'Logistic Regression': {'test': [0.79114, 0.78462, 0.72857, 0.75556],
#    'train_score': {'train': [0.78889, 0.82578, 0.74062, 0.78089]}}},
#  {'Decision Tree': {'test': [0.6962, 0.64865, 0.68571, 0.66667],
#    'train_score': {'train': [0.99683, 1.0, 0.99375, 0.99687]}}},
#  {'Random Forest': {'test': [0.76582, 0.73239, 0.74286, 0.73759],
#    'train_score': {'train': [0.99683, 0.99688, 0.99688, 0.99688]}}},
#  {'K-Nearest Neighbors': {'test': [0.76582, 0.71429, 0.78571, 0.7483],
#    'train_score': {'train': [0.83968, 0.83692, 0.85, 0.84341]}}},
#  {'Neural Network': {'test': [0.76582, 0.69412, 0.84286, 0.76129],
#    'train_score': {'train': [0.80952, 0.79762, 0.8375, 0.81707]}}},
#  {'Gradient Boosting': {'test': [0.78481, 0.75714, 0.75714, 0.75714],
#    'train_score': {'train': [0.95873, 0.96519, 0.95312, 0.95912]}}},
#  {'LightGBM': {'test': [0.78481, 0.74324, 0.78571, 0.76389],
#    'train_score': {'train': [0.99683, 0.99688, 0.99688, 0.99688]}}},
#  {'CatBoost': {'test': [0.81013, 0.77027, 0.81429, 0.79167],
#    'train_score': {'train': [0.99048, 0.99684, 0.98438, 0.99057]}}},
#  {'GNB': {'test': [0.67089, 0.84615, 0.31429, 0.45833],
#    'train_score': {'train': [0.66984, 0.87333, 0.40938, 0.55745]}}},
#  {'Adaboost': {'test': [0.76582, 0.72, 0.77143, 0.74483],
#    'train_score': {'train': [0.88571, 0.88994, 0.88438, 0.88715]}}},
#  {'Adaboost_LSVC': {'test': [0.78481, 0.76471, 0.74286, 0.75362],
#    'train_score': {'train': [0.78413, 0.80065, 0.76562, 0.78275]}}},
#  {'Keras_Tuned': {'test': [0.79747, 0.75, 0.81429, 0.78082]}},
#  {'Keras_Tuned': {'train': [0.80476, 0.81672, 0.79375, 0.80507]}}]

# %% [markdown]
# # Spotify API to get songs features and predict

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="3f27ae63f74843ba9f372448388ae599",
                                                           client_secret="916b7434b6924e0ab3d7c859e40d9d22"))

# %%
def get_songs_features(ids):
    meta = sp.track(ids)
    features = sp.audio_features(ids)

    # meta
    name = meta['name']
    album = meta['album']['name']
    artist = meta['album']['artists'][0]['name']
    release_date = meta['album']['release_date']
    length = meta['duration_ms']
    popularity = meta['popularity']
    ids =  meta['id']

    # features
    acousticness = features[0]['acousticness']
    danceability = features[0]['danceability']
    energy = features[0]['energy']
    instrumentalness = features[0]['instrumentalness']
    liveness = features[0]['liveness']
    valence = features[0]['valence']
    loudness = features[0]['loudness']
    speechiness = features[0]['speechiness']
    tempo = features[0]['tempo']
    key = features[0]['key']
    time_signature = features[0]['time_signature']

    track = [name, album, artist, ids, release_date, popularity, length, danceability, acousticness,
            energy, instrumentalness, liveness, valence, loudness, speechiness, tempo, key, time_signature]
    columns = ['name','album','artist','id','release_date','popularity','length','danceability','acousticness','energy','instrumentalness',
                'liveness','valence','loudness','speechiness','tempo','key','time_signature']
    return track,columns

# %% [markdown]
# # Fitting best model and exporting as pkl model file for application

# %%
model = LinearSVC(random_state=15)
model.fit(X_train, y_train.values.ravel())
y_pred = model.predict(X_test) # make prediction

# test recall and f1-score
scores = test_scores(y_test,y_pred)
print(scores)

import pickle
# save the model to disk
filename = 'LSVC_best.pkl'
pickle.dump(model, open(filename, 'wb'))
# Out:
# {'test': [0.82278, 0.8, 0.8, 0.8]}

# %% [markdown]
# # Use clean unscaled dataset to predict using pipeline

# %%
col_features = df.columns[7:-3]
# scaler = MinMaxScaler()
# df1 = scaler.fit_transform(df[col_features])

X = pd.DataFrame(df, columns = col_features)
y = df[['mood']]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=15)

# %%
# Return Postive or Negative of the track by artist and track
def get_song(artist,track,model):
    # pipline
    seed = 20
    tf.random.set_seed(seed)
    
#     pip = Pipeline([('minmaxscaler',MinMaxScaler()),('keras',model)])
    pip = Pipeline([('minmaxscaler',MinMaxScaler()),('bestmodel', model)])       
#     pip = Pipeline([('StandardScaler',StandardScaler()),('keras',KerasClassifier(model=base_model,epochs=300,
#                                                                              batch_size=100,verbose=0))])
    
    #Fit into the Pipeline
    pip.fit(X_train,y_train.values.ravel())
    results = sp.search(q='artist:' + artist + ' track:' + track, type='track')
    song_id = results['tracks']['items'][0]['id']
#     print('song_id: '+song_id)
    
    song_feature = get_songs_features(song_id)
    song_feature = np.array(song_feature[0][6:-2]).reshape(-1,1).T
    song_feature = pd.DataFrame(song_feature, columns = col_features)
    mood = pip.predict(song_feature)
    mood = 'Positive' if mood == 1 else 'Negative'
    return print(f"{track} by {artist} is a {mood} song")

# %%
check_list = [('Vampire Weekend','A-Punk'),('Linkin Park','Battle Symphony'),
              ('The Fratellis','Chelsea Dagger'),('Justin Bieber','Peaches'),
              ('MKTO','Classic'),('Pharrell Williams','Happy'),('Ed Sheeran','Photograph'),
              ('Sam Smith','I am not the only one')]

# Best model SVC, thrown into pipeline to fit and transform
model = LinearSVC(random_state=15)
for artist,track in check_list:
    get_song(artist,track,model)
# Out:
# A-Punk by Vampire Weekend is a Positive song
# Battle Symphony by Linkin Park is a Positive song
# Chelsea Dagger by The Fratellis is a Negative song
# Peaches by Justin Bieber is a Negative song
# Classic by MKTO is a Positive song
# Happy by Pharrell Williams is a Positive song
# Photograph by Ed Sheeran is a Negative song
# I am not the only one by Sam Smith is a Negative song

# %%
# Importing models
# model = pickle.load(open('LSVC_best.pkl', 'rb'))
